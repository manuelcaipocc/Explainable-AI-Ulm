# %% [markdown]
# ### COMMON INSTRUCTIONS
# Make sure to follow these instructions in order to ensure your submission is gradeable. If the automatic grading fails (check via Validate), no points are assigned!
# 1. Before you turn this problem in, make sure everything runs as expected. First, **restart the kernel** (in the menubar, select Kernel $\rightarrow$ Restart) and then **run all cells** (in the menubar, select Cell $\rightarrow$ Run All).
# 2. Make sure you fill in any place that says `YOUR CODE HERE` or "YOUR ANSWER HERE".
# 3. If you work in a group, please always work and submit in a shared server under the name of your group.
#    If you work alone, then always work and submit on the server called "My Server".
# 4. Using Large Language Models and other AI tools is discouraged. Do not paste external code, as it can be tracked!
# 5. Do not upload notebooks. Always work in notebooks on the server.
# 6. Do not copy cells inside a notebook. Add a new cell and copy code from another cell if needed.

# %%
# !tar czf myfiles.tar.gz ./*

# %% [markdown]
# ---

# %% [markdown]
# # eXplainable AI, Assignment 1

# %% [markdown]
# # Ulm University - Institute of Artificial Intelligence

# %% [markdown]
# # Summer term 2026 - Due: Apr 22, 2026, 2pm

# %% [markdown]
# --------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Task 1 - Formulating Explanations - 6 points

# %% [markdown]
# ![Image](dog.png)
#
# Consider the dog in the Figure above. Imagine your friend Beepo tells you: *"There is a dog in the picture."* You ask back: *"Why is there a dog in the picture?"*

# %% [markdown]
# ### Task 1.1 DN-Model - 2 points
# Formulate a possible explanation by Beepo that adheres to (Hempel’s) Deductive-Nomological Model. Would your explanation still make sense if Beepo is an AI-based robot system or should the AI rather provide a different explanation?

# %% [markdown]
# ```
# Explanans
#
# (
#   Conditions C fulfilled,
#     C1: animal alive,
#     C2: fur visible,
#     C3: four legs visible,
#     C4: snout visible,
#     C5: triangular ears visible,
#     C6: canine-like body shape,
#   AND general law L applies,
#     L: if animal has typical canine features -> it is a dog
# )
#
# Explanandum
#
# Therefore, there is a dog in the picture.
# ```
# If Beepo is an AI based robot, this type of explanation may not reflect how the system reaches its decision, AI systems rely on learned patterns and probabilities rather than explicit general laws, Therefore, a different explanation, such as feature-based would be appropriate

# %% [markdown]
# ### Task 1.2 Flaws of Explanations - 1 point
# How could the explanation you suggested fail to be helpful to you as an explainee? Which property is violated in that case?

# %% [markdown]
# The explanation could fail to be helpful to me because the features mentioned are to generic and they may also apply to similar animals, like a wolf. The violated property is relevance

# %% [markdown]
# ### Task 1.3 Malle's model - 1 points
# Make a suggestion how to formulate your question to Beepo to make Malle’s model of explaining applicable to Beepo's answer. State more general: What kind of questions about the world can have answers formulated in Malle's model?

# %% [markdown]
# Instead of asking "why is there a dog in the picture?" like in the first question, I would ask for a Malle´s context : "why did you say that there is a dog in the picture?" or "Why did you classify the animal as a dog?" Malle´s model applies to questions about an agent´s behavior, actions, intentions, and decisions. It is suitable for explaining why an agent acted in a certain way, which reasons motivated the actions, which priors factos led to it, or which enabling conditions made it possible.

# %% [markdown]
# ### Task 1.4 Malle's model for human actors - 2 points
# Exercise through the suggested question formulation: What would be explanations of (1) causes for *un*intentional behavior, (2) reasons, causal history thereof, and enabling factors for intentional behavior of a human?

# %% [markdown]
# Using the questions "Why did you classify the animal as a dog?", Malle´s model for a human actor could be applied as follows:
#
# 1. Cause for unintentional behavior
#    "because the animal immediately caught my attention"
# 2. Reason for intentional behavior
#    Because I believed that the visible features matched those of a dog and I wanted to classify correctly.
# 3. Causal History of the reason
#    Because I have seen dogs many times before and learned to recognize their appereance
# 4.  Enebling factor for intentional behavior
#    Because the image was clear enough for me to see the relevant features, such snout, ears and body shape

# %% [markdown]
# ## Task 2 - Formulating Explanations - 6 points

# %% [markdown]
# ![Image](crash.png)
#
# See the Figure above. Imagine that the human appears on the robot’s planned trajectory (straight ahead - marked with an arrow) 3 meters in front of the robot and the robot hits the human. *Why did the robot hit the human?*

# %% [markdown]
# ### Task 2.1 Unintentional vs intentional behavior for AI - 2 point
# What could be considered intentional and what unintentional behavior of the robot system?

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# ### Task 2.2 Malle’s model of explanations - 2 points
# Form two possible explanations of the depicted situation of an (un)intentional behavior based on Malle’s model. Which quality signs does your explanation show according to Miller?

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# ### Task 2.3 Contrastive explanations - 1 point
# Formulate an explicitly contrastive "why"-explanation for the depicted situation in Miller’s sense.

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# ### Task 2.4 XAI Aspects - 1 point
#
# Consider the following details about the scenario that the developer of the robot tells you: *"We have experienced similarly strange behavior previously for the AI models we received from our subcontractor. I would like to understand what reasoning the model generally applies such that we can fix flaws using external monitoring. Unfortunately, we don't have access to the model internals, though."*
#
# What properties would you attest / suggest an explainable AI system that supports the developer in their quest? In particular, what can you say about locality (why or how?), ante- vs. post-hoc, portability, and what and how to explain?

# %% [markdown]
# YOUR ANSWER HERE
